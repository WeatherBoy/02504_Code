# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Ex 1.1
# Given four points in homogeneous coordinates write them in inhomogeneous coordinates.
#
# $$
#     \begin{bmatrix}
#         1 \\
#         2 \\
#         1
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         4 \\
#         2 \\
#         2
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         6 \\
#         4 \\
#         -1
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         5 \\
#         3 \\
#         0.5
#     \end{bmatrix}
# $$

# %% [markdown]
# ### Response
# Inhomogenous coordinates:
# $$
#     \begin{bmatrix}
#         1 \\
#         2
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         2 \\
#         1
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         -6 \\
#         -4
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         10 \\
#         6
#     \end{bmatrix}
# $$

# %% [markdown]
# ## Ex 1.2
# We have four points in 3D:
# $$
#     \begin{bmatrix}
#         1 \\
#         10 \\
#         -3 \\
#         1
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         2 \\
#         -4 \\
#         1.1 \\
#         2
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         0 \\
#         0 \\
#         -1 \\
#         10
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         -15 \\
#         3 \\
#         6 \\
#         3
#     \end{bmatrix},
# $$
#
# and want to find their corresponding inhomogeneous coordinates $\pmb{Q}_i$:

# %% [markdown]
# ### Response
#
# $$
#     \begin{bmatrix}
#         1 \\
#         10 \\
#         -3
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         1 \\
#         -2 \\
#         0.55
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         0 \\
#         0 \\
#         -0.1
#     \end{bmatrix},
#
#     \begin{bmatrix}
#         -5 \\
#         1 \\
#         2
#     \end{bmatrix},
# $$
#
# $\textcolor{magenta}{\text{We think this is correct}}$.
#
# $\textcolor{cyan}{\text{Confirmed correct from solution}}$.

# %% [markdown]
# ## Ex 1.3
# A 2D line is given as:
# $$
#     x + 2y = 3
# $$
#
# write this line in homogeneous form i.e. $\pmb{l}^T \pmb{p} = 0 $.

# %% [markdown]
# ### Response
# $$
#     \begin{bmatrix}
#         1 \\
#         2 \\
#         -3
#     \end{bmatrix}
#     \begin{bmatrix}
#         x \\
#         y \\
#         1
#     \end{bmatrix}
# $$

# %% [markdown]
# ## Ex 1.4
# Using $\pmb{l}$ from Exercise 1.3, which of the following 2D points are on this line?
# $$
#     \pmb{p}_1 =
#     \begin{bmatrix}
#         3 \\
#         0 \\
#         1
#     \end{bmatrix},
#
#     \pmb{p}_2 =
#     \begin{bmatrix}
#         6 \\
#         0 \\
#         2
#     \end{bmatrix},
#
#     \pmb{p}_3 =
#     \begin{bmatrix}
#         1 \\
#         1 \\
#         2
#     \end{bmatrix},
#
#     \pmb{p}_4 =
#     \begin{bmatrix}
#         1 \\
#         1 \\
#         1
#     \end{bmatrix},
#
#     \pmb{p}_5 =
#     \begin{bmatrix}
#         110 \\
#         -40 \\
#         10
#     \end{bmatrix},
#
#     \pmb{p}_6 =
#     \begin{bmatrix}
#         11 \\
#         4 \\
#         1
#     \end{bmatrix},
# $$

# %% [markdown]
# ### Response

# %%
import numpy as np
p1 = np.array([3, 0, 1])
p2 = np.array([6, 0, 2])
p3 = np.array([1, 1, 2])
p4 = np.array([1, 1, 1])
p5 = np.array([110, -40, 10])
p6 = np.array([11, 4, 1])

all_points = [p1, p2, p3, p4, p5, p6]

ex3_line = np.array([1, 2, -3])
for i, point in enumerate(all_points):
    if point @ ex3_line == 0:
        print(f"Point {i + 1} is on the line!")
    else:
        print(f"Point {i + 1} is NOT on the line...")
# Out:
# Point 1 is on the line!
# Point 2 is on the line!
# Point 3 is NOT on the line...
# Point 4 is on the line!
# Point 5 is on the line!
# Point 6 is NOT on the line...

# %% [markdown]
# ## Ex 1.5
#
# Given the two lines
#
# $$
#     \pmb{l}_0 =
#     \begin{bmatrix}
#         1 \\
#         1 \\
#         -1
#     \end{bmatrix},
#     \qquad
#     \pmb{l}_1 =
#     \begin{bmatrix}
#         -1 \\
#         1 \\
#         -3
#     \end{bmatrix}
# $$
#
# what is their point of intersection $\pmb{q}_{\pmb{I}}$?

# %% [markdown]
# ### Response

# %%
import sympy
from sympy.abc import x, y
print(sympy.solve([x + y - 1, -x + y - 3], [x,y]))
# Out:
# {x: -1, y: 2}

# %% [markdown]
# ## Ex 1.6
#
# Consider the following matrix:
#
# $$
#     \pmb{A} =
#     \begin{bmatrix}
#         10 & 0  & 2 \\
#         0  & 10 & -3 \\
#         0  & 0  & 1
#     \end{bmatrix}
# $$
#
# What is the result of $\pmb{A}\pmb{p} = \pmb{q}$, where $\pmb{p}$ and $\pmb{q}$ are 2D points in the homogeneous coordinates?
#
# Explain what each of the (non-zero) coefficients in $\pmb{A}$ does to the coordinates of $\pmb{q}$.

# %% [markdown]
# ### Response
# $\pmb{A}$ is the camera matrix $\pmb{K}$.
#
# So it scales by the focal length $f = 10$ and then does the translation $\delta_x = 2, \delta_y = -3$.

# %% [markdown]
# ## Ex 1.7
#
# A new line is given:
# $$
#     \pmb{l} =
#     \begin{bmatrix}
#         \frac{1}{\sqrt{2}} \\
#         \frac{1}{\sqrt{2}} \\
#         -1
#     \end{bmatrix}
# $$
#
# What is the (shortest) distance between the line $\pmb{l}$ and the points:
# $$
#     \pmb{p}_1 =
#     \begin{bmatrix}
#         0 \\
#         0 \\
#         1
#     \end{bmatrix},
#
#     \pmb{p}_2 =
#     \begin{bmatrix}
#         \sqrt{2} \\
#         \sqrt{2} \\
#         1
#     \end{bmatrix},
#
#     \pmb{p}_3 =
#     \begin{bmatrix}
#         \sqrt{2} \\
#         \sqrt{2} \\
#         4
#     \end{bmatrix},
# $$

# %% [markdown]
# ### Response
#
# Alex is big smart and said we should utilize the distance formula:
# $$
#     dist(p, q) = \frac{|p \cdot q|}{\sqrt{a^2 + b^2}}
# $$

# %%
import math

p1 = np.array([0, 0, 1])
p2 = np.array([math.sqrt(2), math.sqrt(2), 1])
p3 = np.array([math.sqrt(2), math.sqrt(2), 4])

a = 1/(math.sqrt(2))
b = 1/(math.sqrt(2))

points = [p1, p2, p3]

line = np.array([a, b, -1])

for i, point in enumerate(points):
    dist = abs(point @ line) / (math.sqrt(a**2 + b**2))
    print(f"Closest distance to point {i} is: {dist}")
# Out:
# Closest distance to point 0 is: 1.0000000000000002
# Closest distance to point 1 is: 1.0000000000000002
# Closest distance to point 2 is: 2.0000000000000004

# %% [markdown]
# ## Ex 1.8
#
# Repeat exercise 1.7 with:
# $$
#     \pmb{l} =
#     \begin{bmatrix}
#         2 \\
#         2 \\
#         -1
#     \end{bmatrix}
# $$

# %% [markdown]
# ### Response

# %%
a = 2
b = 2

line = np.array([a, b, -1])

for i, point in enumerate(points):
    dist = abs(point @ line) / (math.sqrt(a**2 + b**2))
    print(f"Closest distance to point {i} is: {dist}")
# Out:
# Closest distance to point 0 is: 0.35355339059327373
# Closest distance to point 1 is: 1.6464466094067263
# Closest distance to point 2 is: 0.5857864376269051

# %% [markdown]
# ## Ex 1.9
#
# install OpenCV 4.4.0 or later

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.6.0

# %% [markdown]
# ## Ex 1.10
#
# * Capture an image with a camera
# * Transfer it to your computer
# * Load it with OpenCV
# * Display it with Matplotlib

# %% [markdown]
# ### Response

# %%
import matplotlib.pyplot as plt

img = cv2.imread("ims\Lauge_spiser.jpg")
rgb_im = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_im)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Ex 1.11
# Wall of text $^{TM}$.
#
# ...*Oh my god! there is so much text*

# %% [markdown]
# ### Response
# Just copied the lecturer's code

# %%
import itertools as it

def box3d(n=16):
    points = []
    N = tuple(np.linspace(-1, 1, n))
    
    for i, j in [(-1, -1), (-1, 1), (1, 1), (0, 0)]:
        points.extend(set(it.permutations([(i, )*n, (j, )*n, N])))
        
    return np.hstack(points)/2

# %% [markdown]
# ## Ex 1.12
# Implement two helper functions:
#
# * $\texttt{Pi}$ that converts from homogeneous to inhomogeneous coordinates, and
# * $\texttt{PiInv}$ that converts from inhomogeneous to homogeneous coordinates.
#
# The functions should take Numpy arrays with size (dimension of point × number of points) as
# their input.
#
# *Tip*: To add homogeneous coordinate to a matrix you can use $\texttt{np.vstack}$ with $\texttt{np.ones}$.
#
# *Tip*: You can divide by and remove the last coordinate by doing $\texttt{p = ph[:-1]/ph[-1]}$

# %% [markdown]
# ### Response

# %%
def pi(points : np.ndarray) -> np.ndarray:
    """
        Converts from homogeneous to inhomogeneous coordinates
    """
    p = points[:-1]/points[-1]
    
    return p

def piInv(points : np.ndarray) -> np.ndarray:
    """
        Converts from inhomogeneous to homogeneous coordinates
    """
    
    # Gets the amount of points by using shape
    _, num_points = points.shape
    
    # Stacks the scale s at the bottom of the matrix
    ph = np.vstack((points, np.ones(num_points)))
    
    return ph

# %% [markdown]
# ## Ex 1.13
# Wall of text $^{TM}$.

# %% [markdown]
# ### Response

# %%
def projectPoints(K, Rt, Q):
    
    Q_hom = piInv(Q)
    points = K @ Rt @ Q_hom
    points_inhom = pi(points)
    
    return points_inhom

# %% [markdown]
# #### Test of function

# %%
K = np.diag(np.ones(3))
R = np.diag(np.ones(3))
t = np.array([[0, 0, 4]])
Rt = np.concatenate((R, t.T), axis=1)

Q = box3d()

Qp = projectPoints(K, Rt, Q)

plt.scatter(Qp[0, :], Qp[1, :])
plt.show()

# %% [markdown]
# ## Ex 1.14
#
# We try instead with another $\pmb{R}$.

# %% [markdown]
# ### Response

# %%
theta = math.pi / 6

R2 = np.array(
    [[math.cos(theta), 0, math.sin(theta)],
     [0, 1, 0],
     [-math.sin(theta), 0, math.cos(theta)]]
    )

Rt2 = np.concatenate((R2, t.T), axis=1)

Qp2 = projectPoints(K, Rt2, Q)

plt.scatter(Qp2[0, :], Qp2[1, :])
plt.show()

# %% [markdown]
# ## Ex 1.15
#
# Funtime now!

# %% [markdown]
# ### Response

# %%
theta = math.pi / 3

R3 = np.array(
    [[math.cos(theta), 0, math.sin(theta)],
     [0, 1, 0],
     [-math.sin(theta), 0, math.cos(theta)]]
    )

t3 = np.array([[0, 0, 20]])

Rt3 = np.concatenate((R3, t3.T), axis=1)

Qp3 = projectPoints(K, Rt3, Q)

plt.scatter(Qp3[0, :], Qp3[1, :])
plt.show()

# %%
theta = math.pi / 2

R4 = np.array(
    [[math.cos(theta), 0, math.sin(theta)],
     [0, 1, 0],
     [-math.sin(theta), 0, math.cos(theta)]]
    )

t4 = np.array([[-3, 20, -10]])

Rt4 = np.concatenate((R4, t4.T), axis=1)

Qp4 = projectPoints(K, Rt4, Q)

plt.scatter(Qp4[0, :], Qp4[1, :])
plt.show()
